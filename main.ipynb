# %%
import fastbook
fastbook.setup_book()

# %%
#hide
from fastbook import *
from fastai.vision.widgets import *

# %% [markdown]
# ## Turning Your Model into an Online Application

# %% [markdown]
# ### Using the Model for Inference

# %%
#  learn.export()

# %%
path = Path()
path.ls(file_exts='.pkl')
# Out:
# (#1) [Path('export.pkl')]

# %%
learn_inf = load_learner(path/'export.pkl')

# %%
learn_inf.predict(path/'images/german_shepherd.jpg')
# Out:
# ('german shepherd', tensor(2), tensor([2.4385e-06, 1.3935e-06, 1.0000e+00]))

# %%
learn_inf.dls.vocab
# Out:
# ['beagle', 'dachshund', 'german shepherd']

# %% [markdown]
# ### Creating a Notebook App from the Model

# %%
btn_upload = widgets.FileUpload()
btn_upload
# Out:
# FileUpload(value={}, description='Upload')

# %%
#hide
# For the book, we can't actually click an upload button, so we fake it
btn_upload = SimpleNamespace(data = ['images/german_shepherd.jpg'])

# %%
img = PILImage.create(btn_upload.data[-1])

# %%
out_pl = widgets.Output()
out_pl.clear_output()
with out_pl: display(img.to_thumb(128,128))
out_pl
# Out:
# Output()

# %%
pred,pred_idx,probs = learn_inf.predict(img)

# %%
lbl_pred = widgets.Label()
lbl_pred.value = f'Prediction: {pred}; Probability: {probs[pred_idx]:.04f}'
lbl_pred
# Out:
# Label(value='Prediction: german shepherd; Probability: 1.0000')

# %%
btn_run = widgets.Button(description='Classify')
btn_run
# Out:
# Button(description='Classify', style=ButtonStyle())

# %%
def on_click_classify(change):
    img = PILImage.create(btn_upload.data[-1])
    out_pl.clear_output()
    with out_pl: display(img.to_thumb(128,128))
    pred,pred_idx,probs = learn_inf.predict(img)
    lbl_pred.value = f'Prediction: {pred}; Probability: {probs[pred_idx]:.04f}'

btn_run.on_click(on_click_classify)

# %%
#hide
#Putting back btn_upload to a widget for next cell
btn_upload = widgets.FileUpload()

# %%
VBox([widgets.Label('Select your dog!'), 
      btn_upload, btn_run, out_pl, lbl_pred])
# Out:
# VBox(children=(Label(value='Select your dog!'), FileUpload(value={}, description='Upload'), Button(description…

# %% [markdown]
# ### Turning Your Notebook into a Real App

# %%
#hide
# !pip install voila
# !jupyter serverextension enable --sys-prefix voila
# Out:
# Collecting voila
#   Downloading voila-0.4.0-py3-none-any.whl (5.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 9.7 MB/s eta 0:00:00:00:0100:01m
# Collecting websockets>=9.0
#   Downloading websockets-11.0.2-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (129 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 KB 16.2 MB/s eta 0:00:00
# Collecting jupyter-server<2.0.0,>=1.18
#   Downloading jupyter_server-1.24.0-py3-none-any.whl (347 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 347.5/347.5 KB 39.9 MB/s eta 0:00:00
# Requirement already satisfied: nbconvert<8,>=6.4.5 in ./env_project/lib/python3.10/site-packages (from voila) (7.3.1)
# Collecting jupyter-client<=7.4.1,>=6.1.3
#   Downloading jupyter_client-7.4.1-py3-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.1/132.1 KB 12.3 MB/s eta 0:00:00
# Requirement already satisfied: traitlets<6,>=5.0.3 in ./env_project/lib/python3.10/site-packages (from voila) (5.9.0)
# Requirement already satisfied: nbclient<0.8,>=0.4.0 in ./env_project/lib/python3.10/site-packages (from voila) (0.7.4)
# Collecting jupyterlab-server<3,>=2.3.0
#   Downloading jupyterlab_server-2.22.1-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.0/57.0 KB 6.6 MB/s eta 0:00:00
# Requirement already satisfied: jupyter-core>=4.11.0 in ./env_project/lib/python3.10/site-packages (from voila) (5.3.0)
# Requirement already satisfied: nest-asyncio>=1.5.4 in ./env_project/lib/python3.10/site-packages (from jupyter-client<=7.4.1,>=6.1.3->voila) (1.5.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./env_project/lib/python3.10/site-packages (from jupyter-client<=7.4.1,>=6.1.3->voila) (2.8.2)
# Requirement already satisfied: pyzmq>=23.0 in ./env_project/lib/python3.10/site-packages (from jupyter-client<=7.4.1,>=6.1.3->voila) (25.0.2)
# Requirement already satisfied: tornado>=6.2 in ./env_project/lib/python3.10/site-packages (from jupyter-client<=7.4.1,>=6.1.3->voila) (6.3.1)
# Collecting entrypoints
#   Downloading entrypoints-0.4-py3-none-any.whl (5.3 kB)
# Requirement already satisfied: platformdirs>=2.5 in ./env_project/lib/python3.10/site-packages (from jupyter-core>=4.11.0->voila) (3.5.0)
# Requirement already satisfied: prometheus-client in ./env_project/lib/python3.10/site-packages (from jupyter-server<2.0.0,>=1.18->voila) (0.16.0)
# Requirement already satisfied: nbformat>=5.2.0 in ./env_project/lib/python3.10/site-packages (from jupyter-server<2.0.0,>=1.18->voila) (5.8.0)
# Requirement already satisfied: argon2-cffi in ./env_project/lib/python3.10/site-packages (from jupyter-server<2.0.0,>=1.18->voila) (21.3.0)
# Requirement already satisfied: anyio<4,>=3.1.0 in ./env_project/lib/python3.10/site-packages (from jupyter-server<2.0.0,>=1.18->voila) (3.6.2)
# Requirement already satisfied: packaging in ./env_project/lib/python3.10/site-packages (from jupyter-server<2.0.0,>=1.18->voila) (23.1)
# Requirement already satisfied: Send2Trash in ./env_project/lib/python3.10/site-packages (from jupyter-server<2.0.0,>=1.18->voila) (1.8.2)
# Requirement already satisfied: websocket-client in ./env_project/lib/python3.10/site-packages (from jupyter-server<2.0.0,>=1.18->voila) (1.5.1)
# Requirement already satisfied: jinja2 in ./env_project/lib/python3.10/site-packages (from jupyter-server<2.0.0,>=1.18->voila) (3.1.2)
# Requirement already satisfied: terminado>=0.8.3 in ./env_project/lib/python3.10/site-packages (from jupyter-server<2.0.0,>=1.18->voila) (0.17.1)
# Collecting babel>=2.10
#   Downloading Babel-2.12.1-py3-none-any.whl (10.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 20.2 MB/s eta 0:00:0000:010:01
# Collecting json5>=0.9.0
#   Downloading json5-0.9.11-py2.py3-none-any.whl (19 kB)
# Requirement already satisfied: jsonschema>=4.17.3 in ./env_project/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.3.0->voila) (4.17.3)
# Requirement already satisfied: requests>=2.28 in ./env_project/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.3.0->voila) (2.29.0)
# Requirement already satisfied: tinycss2 in ./env_project/lib/python3.10/site-packages (from nbconvert<8,>=6.4.5->voila) (1.2.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in ./env_project/lib/python3.10/site-packages (from nbconvert<8,>=6.4.5->voila) (1.5.0)
# Requirement already satisfied: jupyterlab-pygments in ./env_project/lib/python3.10/site-packages (from nbconvert<8,>=6.4.5->voila) (0.2.2)
# Requirement already satisfied: mistune<3,>=2.0.3 in ./env_project/lib/python3.10/site-packages (from nbconvert<8,>=6.4.5->voila) (2.0.5)
# Requirement already satisfied: pygments>=2.4.1 in ./env_project/lib/python3.10/site-packages (from nbconvert<8,>=6.4.5->voila) (2.15.1)
# Requirement already satisfied: defusedxml in ./env_project/lib/python3.10/site-packages (from nbconvert<8,>=6.4.5->voila) (0.7.1)
# Requirement already satisfied: bleach in ./env_project/lib/python3.10/site-packages (from nbconvert<8,>=6.4.5->voila) (6.0.0)
# Requirement already satisfied: beautifulsoup4 in ./env_project/lib/python3.10/site-packages (from nbconvert<8,>=6.4.5->voila) (4.12.2)
# Requirement already satisfied: markupsafe>=2.0 in ./env_project/lib/python3.10/site-packages (from nbconvert<8,>=6.4.5->voila) (2.1.2)
# Requirement already satisfied: sniffio>=1.1 in ./env_project/lib/python3.10/site-packages (from anyio<4,>=3.1.0->jupyter-server<2.0.0,>=1.18->voila) (1.3.0)
# Requirement already satisfied: idna>=2.8 in ./env_project/lib/python3.10/site-packages (from anyio<4,>=3.1.0->jupyter-server<2.0.0,>=1.18->voila) (3.4)
# Requirement already satisfied: attrs>=17.4.0 in ./env_project/lib/python3.10/site-packages (from jsonschema>=4.17.3->jupyterlab-server<3,>=2.3.0->voila) (23.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in ./env_project/lib/python3.10/site-packages (from jsonschema>=4.17.3->jupyterlab-server<3,>=2.3.0->voila) (0.19.3)
# Requirement already satisfied: fastjsonschema in ./env_project/lib/python3.10/site-packages (from nbformat>=5.2.0->jupyter-server<2.0.0,>=1.18->voila) (2.16.3)
# Requirement already satisfied: six>=1.5 in ./env_project/lib/python3.10/site-packages (from python-dateutil>=2.8.2->jupyter-client<=7.4.1,>=6.1.3->voila) (1.16.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./env_project/lib/python3.10/site-packages (from requests>=2.28->jupyterlab-server<3,>=2.3.0->voila) (2022.12.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./env_project/lib/python3.10/site-packages (from requests>=2.28->jupyterlab-server<3,>=2.3.0->voila) (3.1.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in ./env_project/lib/python3.10/site-packages (from requests>=2.28->jupyterlab-server<3,>=2.3.0->voila) (1.26.15)
# Requirement already satisfied: ptyprocess in ./env_project/lib/python3.10/site-packages (from terminado>=0.8.3->jupyter-server<2.0.0,>=1.18->voila) (0.7.0)
# Requirement already satisfied: argon2-cffi-bindings in ./env_project/lib/python3.10/site-packages (from argon2-cffi->jupyter-server<2.0.0,>=1.18->voila) (21.2.0)
# Requirement already satisfied: soupsieve>1.2 in ./env_project/lib/python3.10/site-packages (from beautifulsoup4->nbconvert<8,>=6.4.5->voila) (2.4.1)
# Requirement already satisfied: webencodings in ./env_project/lib/python3.10/site-packages (from bleach->nbconvert<8,>=6.4.5->voila) (0.5.1)
# Requirement already satisfied: cffi>=1.0.1 in ./env_project/lib/python3.10/site-packages (from argon2-cffi-bindings->argon2-cffi->jupyter-server<2.0.0,>=1.18->voila) (1.15.1)
# Requirement already satisfied: pycparser in ./env_project/lib/python3.10/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server<2.0.0,>=1.18->voila) (2.21)
# Installing collected packages: json5, websockets, entrypoints, babel, jupyter-client, jupyter-server, jupyterlab-server, voila
#   Attempting uninstall: jupyter-client
#     Found existing installation: jupyter_client 8.2.0
#     Uninstalling jupyter_client-8.2.0:
#       Successfully uninstalled jupyter_client-8.2.0
#   Attempting uninstall: jupyter-server
#     Found existing installation: jupyter_server 2.5.0
#     Uninstalling jupyter_server-2.5.0:
#       Successfully uninstalled jupyter_server-2.5.0
# Successfully installed babel-2.12.1 entrypoints-0.4 json5-0.9.11 jupyter-client-7.4.1 jupyter-server-1.24.0 jupyterlab-server-2.22.1 voila-0.4.0 websockets-11.0.2
# Enabling: voila
# - Writing config: /home/arthur/Documents/UFPE/6 PERIODO/INGLES/test/env_project/etc/jupyter
#     - Validating...
#       voila 0.4.0 OK

# %% [markdown]
# ### Deploying your app

# %% [markdown]
# ## How to Avoid Disaster

# %% [markdown]
# ### Unforeseen Consequences and Feedback Loops

# %% [markdown]
# ## Get Writing!

# %% [markdown]
# ## Questionnaire

# %% [markdown]
# 1. Provide an example of where the bear classification model might work poorly in production, due to structural or style differences in the training data.
# 1. Where do text models currently have a major deficiency?
# 1. What are possible negative societal implications of text generation models?
# 1. In situations where a model might make mistakes, and those mistakes could be harmful, what is a good alternative to automating a process?
# 1. What kind of tabular data is deep learning particularly good at?
# 1. What's a key downside of directly using a deep learning model for recommendation systems?
# 1. What are the steps of the Drivetrain Approach?
# 1. How do the steps of the Drivetrain Approach map to a recommendation system?
# 1. Create an image recognition model using data you curate, and deploy it on the web.
# 1. What is `DataLoaders`?
# 1. What four things do we need to tell fastai to create `DataLoaders`?
# 1. What does the `splitter` parameter to `DataBlock` do?
# 1. How do we ensure a random split always gives the same validation set?
# 1. What letters are often used to signify the independent and dependent variables?
# 1. What's the difference between the crop, pad, and squish resize approaches? When might you choose one over the others?
# 1. What is data augmentation? Why is it needed?
# 1. What is the difference between `item_tfms` and `batch_tfms`?
# 1. What is a confusion matrix?
# 1. What does `export` save?
# 1. What is it called when we use a model for getting predictions, instead of training?
# 1. What are IPython widgets?
# 1. When might you want to use CPU for deployment? When might GPU be better?
# 1. What are the downsides of deploying your app to a server, instead of to a client (or edge) device such as a phone or PC?
# 1. What are three examples of problems that could occur when rolling out a bear warning system in practice?
# 1. What is "out-of-domain data"?
# 1. What is "domain shift"?
# 1. What are the three steps in the deployment process?

# %% [markdown]
# ### Further Research

# %% [markdown]
# 1. Consider how the Drivetrain Approach maps to a project or problem you're interested in.
# 1. When might it be best to avoid certain types of data augmentation?
# 1. For a project you're interested in applying deep learning to, consider the thought experiment "What would happen if it went really, really well?"
# 1. Start a blog, and write your first blog post. For instance, write about what you think deep learning might be useful for in a domain you're interested in.
